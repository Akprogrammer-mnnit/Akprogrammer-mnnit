# %% [markdown]
# <a href="https://colab.research.google.com/github/Akprogrammer-mnnit/Akprogrammer-mnnit/blob/main/AI_Scientist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Akprogrammer-mnnit/AI-Scientist
# Out:
# Cloning into 'AI-Scientist'...
# fatal: could not read Username for 'https://github.com': No such device or address
